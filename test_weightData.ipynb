# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import fnViz as fn
import plotly.graph_objects as go

# %%
df = pd.read_csv('./PBL_data/weight_data_0.csv')

# %%
measuredt = df['Measure Date Time'].str.split('T', expand = True)
df[['date', 'time']] = measuredt

# %%
df['BMI'].mean()
# Out:
# 22.704727272727272

# %%
df
# Out:
#             subject_id                                device        serialNo  \
# 0    cefoxSR1601000701  281E8A53-A28A-45F0-8A35-8707835EB919   180301108F_SW
# 1    cefoxSR1601000701  281E8A53-A28A-45F0-8A35-8707835EB919   180301108F_SW
# 2    cefoxSR1601000701  281E8A53-A28A-45F0-8A35-8707835EB919   180301108F_SW
# 3    cefoxSR1601000701  281E8A53-A28A-45F0-8A35-8707835EB919   180301108F_SW
# 4    cefoxSR1601000701  281E8A53-A28A-45F0-8A35-8707835EB919   180301108F_SW
# ..                 ...                                   ...             ...
# 270  cefoxSR1707005601  40837A28-34C8-0595-8746-102F0812F093   180301860F_SW
# 271  cefoxSR1707005601  40837A28-34C8-0595-8746-102F0812F093   180301860F_SW
# 272  cefoxSR1707005601  40837A28-34C8-0595-8746-102F0812F093   180301860F_SW
# 273  cefoxSR1707005601  40837A28-34C8-0595-8746-102F0812F093   180301860F_SW
# 274  cefoxSR1707005601  40837A28-34C8-0595-8746-102F0812F093   180301860F_SW
#
# ...
